# %% [markdown]
# # Filtering and Sorting Data: Chipotle

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipotle = pd.read_csv(url, sep = '\t')
#print(chipotle)

# %%
prices = [float(value) for value in chipotle.item_price]

# reassign the column with the cleaned prices
chipotle.item_price = prices

# delete the duplicates in item_name and quantity
chipotle_filtered = chipotle.drop_duplicates(['item_name','quantity','choice_description'])
#print(chipotle_filtered)

# select only the products with quantity equals to 1
chipotle_one_prod = chipotle_filtered[chipotle_filtered.quantity == 1]
#print(chipotle_one_prod)

chipotle.query('item_price > 10')   #.item_name  #.nunique()
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# Step 5. What is the price of each item?
# print a data frame with only two columns item_name and item_price

# %%
chipotle[(chipotle['item_name'] == 'Chicken Bowl') & (chipotle['quantity'] == 1)]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# ...                                                 ...         ...
# ...

# %% [markdown]
# Step 6. Sort by the name of the item

# %%
#chipotle.item_name.sort_values()

chipotle.sort_values(by = "item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# Step 7. What was the quantity of the most expensive item ordered?

# %%
chipotle.sort_values(by = "item_price", ascending = False)   #.head(1)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# ...

# %% [markdown]
# Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipotle_salad = chipotle[chipotle.item_name == "Veggie Salad Bowl"]
print(chipotle_salad)

len(chipotle_salad)
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %% [markdown]
# Step 9. How many times did someone order more than one Canned Soda?

# %%
more_than_one_soda = chipotle[(chipotle.item_name == "Canned Soda") & (chipotle.quantity > 1)]
print(more_than_one_soda)

len(more_than_one_soda)
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9         2  Canned Soda           [Sprite]        2.18
# 51          23         2  Canned Soda     [Mountain Dew]        2.18
# 162         73         2  Canned Soda        [Diet Coke]        2.18
# 171         76         2  Canned Soda  [Diet Dr. Pepper]        2.18
# 350        150         2  Canned Soda        [Diet Coke]        2.18
# 352        151         2  Canned Soda        [Coca Cola]        2.18
# 698        287         2  Canned Soda        [Coca Cola]        2.18
# 700        288         2  Canned Soda        [Coca Cola]        2.18
# 909        376         2  Canned Soda     [Mountain Dew]        2.18
# 1091       450         2  Canned Soda       [Dr. Pepper]        2.18
# 1092       450         2  Canned Soda        [Coca Cola]        2.18
# 1944       787         2  Canned Soda       [Dr. Pepper]        2.18
# 2135       859         2  Canned Soda        [Diet Coke]        2.18
# ...
